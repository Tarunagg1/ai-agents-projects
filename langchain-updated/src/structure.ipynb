# %%
import os
import langchain.chat_models import init_chat_model


os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")


model = init_chat_model(model="groq:qwen/qwen-3.5-32b")

model

# %%
from pydantic import BaseModel,Field

class Movie(BaseModel):
    title: str = Field(description="The title of the movie")
    director: str = Field(description="The director of the movie")
    year: int = Field(description="The year the movie was released")
    rating: float = Field(description="The rating of the movie")

# %%
model_with_structured_output = model.bind_structured_output(Movie)

movie = model_with_structured_output.invoke("What is the best movie ever?")
print(movie)
